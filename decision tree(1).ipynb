# %%
import pandas as pd

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
inputs = df.drop('Profit',axis='columns')

# %%
target = df['Profit']

# %%
from sklearn.preprocessing import LabelEncoder
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['Segment_n'] = le_company.fit_transform(inputs['Segment'])
inputs['City_n'] = le_job.fit_transform(inputs['City'])

# %%
inputs
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
inputs_n = inputs.drop(['Segment','City'],axis='columns')

# %%
inputs_n
# Out:
#            Ship Mode        Country       State  Postal Code Region  \
# 0       Second Class  United States    Kentucky        42420  South
# 1       Second Class  United States    Kentucky        42420  South
# 2       Second Class  United States  California        90036   West
# 3     Standard Class  United States     Florida        33311  South
# 4     Standard Class  United States     Florida        33311  South
# ...              ...            ...         ...          ...    ...
# 9989    Second Class  United States     Florida        33180  South
# 9990  Standard Class  United States  California        92627   West
# 9991  Standard Class  United States  California        92627   West
# 9992  Standard Class  United States  California        92627   West
# 9993    Second Class  United States  California        92683   West
#
#              Category Sub-Category     Sales  Quantity  Discount  Segment_n  \
# ...

# %%
target
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %%
# !pip install scikit-learn

# %%
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
data = {
    'feature1': [1.2, 2.3, 3.1, 4.5],
    'feature2': ['First Class', 'Second Class', 'Second Class', 'First Class'],
    'target': [0, 1, 0, 1]
}
df = pd.DataFrame(data)

# %%
inputs_n = df.drop('target', axis=1)

# %%
target = df['target']

# %%
label_encoder = LabelEncoder()
inputs_n['feature2'] = label_encoder.fit_transform(inputs_n['feature2'])

# %%
inputs_n = inputs_n.fillna(inputs_n.mean())

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 1.0

# %%
model.predict([[2,1]])
# Out:
# D:\python anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
model.predict([[2,1]])
# Out:
# D:\python anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
